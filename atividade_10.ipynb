# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('car_prices.csv')

# %%
data = df.copy()

# %%
data = data.dropna()

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0  white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0   gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0  white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0   gray
# ...             ...                ...   ...        ...       ...    ...
# 558831    automatic  wbafr1c53bc744672    fl       39.0   66403.0  white
# 558833    automatic  3c6td5et6cg112407    wa        5.0   54393.0  white
# 558834    automatic  5uxzw0c58cl668465    ca       48.0   50561.0  black
# 558835    automatic  1n4al3ap0fc216050    ga       38.0   16658.0  white
# 558836    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 558831    brown           lauderdale imports ltd bmw pembrok pines  20300.0
# 558833    black                                    i -5 uhlmann rv  30200.0
# 558834    black             financial services remarketing (lease)  29800.0
# 558835    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558831       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [472325 rows x 16 columns]

# %%
data = data.drop(["trim", "transmission", "vin", "state", "condition", "odometer", "seller", "interior"], axis = 1)

# %%
data
# Out:
#         year    make                model       body  color      mmr  \
# 0       2015     Kia              Sorento        SUV  white  20500.0
# 1       2015     Kia              Sorento        SUV  white  20800.0
# 2       2014     BMW             3 Series      Sedan   gray  31900.0
# 3       2015   Volvo                  S60      Sedan  white  27500.0
# 4       2014     BMW  6 Series Gran Coupe      Sedan   gray  66000.0
# ...      ...     ...                  ...        ...    ...      ...
# 558831  2011     BMW             5 Series      Sedan  white  20300.0
# 558833  2012     Ram                 2500   Crew Cab  white  30200.0
# 558834  2012     BMW                   X5        SUV  black  29800.0
# 558835  2015  Nissan               Altima      sedan  white  15100.0
# 558836  2014    Ford                F-150  SuperCrew   gray  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558831       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [472325 rows x 8 columns]

# %%
carros_2010 = data.loc[lambda dados: dados["year"] == 2010]

# %%
carros_2010
# Out:
#         year        make             model      body   color      mmr  \
# 2465    2010   Chevrolet              Aveo     Sedan     red   5150.0
# 2467    2010       Dodge        Challenger     Coupe   black  10350.0
# 2474    2010   Chevrolet             Tahoe       SUV   white  18150.0
# 2486    2010   Chevrolet           Equinox       SUV    gray  10000.0
# 2493    2010   Chevrolet           Equinox       SUV   beige  15200.0
# ...      ...         ...               ...       ...     ...      ...
# 558689  2010   Chevrolet  Silverado 2500HD  crew cab     red  17400.0
# 558691  2010       Mazda            Mazda6     sedan   white   8225.0
# 558793  2010    Cadillac      Escalade ESV       SUV   black  25400.0
# 558801  2010     Mercury           Mariner       SUV   white   9425.0
# 558802  2010  Volkswagen            Tiguan       SUV  silver   9850.0
#
#         sellingprice                                 saledate
# 2465          5900.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)
# 2467         10500.0  Wed Jan 14 2015 04:30:00 GMT-0800 (PST)
# 2474         16250.0  Wed Dec 17 2014 11:00:00 GMT-0800 (PST)
# 2486         10700.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)
# 2493         12500.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558689       17000.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)
# 558691        9400.0  Fri Jun 19 2015 02:45:00 GMT-0700 (PDT)
# 558793       29000.0  Tue Jul 07 2015 07:00:00 GMT-0700 (PDT)
# 558801        8700.0  Wed Jul 08 2015 07:15:00 GMT-0700 (PDT)
# 558802       14500.0  Tue Jul 07 2015 06:30:00 GMT-0700 (PDT)
#
# [22616 rows x 8 columns]

# %%
num_vendidos = dict(carros_2010.value_counts("make").head())

# %%
num_vendidos.items()
# Out:
# dict_items([('Ford', 3534), ('Chevrolet', 3347), ('Dodge', 2421), ('Toyota', 1991), ('Honda', 1313)])

# %%
sns.set()

f, ax = plt.subplots(figsize = (15, 5))

ax.bar_label(ax.bar(num_vendidos.keys(), num_vendidos.values()), padding = 0.3)
ax.bar(num_vendidos.keys(), num_vendidos.values(), color = sns.mpl_palette("Set2"))
#sns.barplot(data = num_vendidos, x = num_vendidos.keys(), y = num_vendidos.values, color = sns.mlp_palette("Set2" ))
ax.set_title("Top 5 Carros mais Vendidos do ano 2010")
ax.set_xlabel("Nomes da Marca")
ax.set_ylabel("Vendas em números absolutos")
ax.set_ylim((0, 6000))
# Out:
# (0.0, 6000.0)

# %%
data['body'] = [nome.upper() for nome in data['body']]

# %%
carros_ford = data.loc[(data['year']==2010)&(data['make'] == "Ford")]

# %%
carros_ford
# Out:
#         year  make             model         body   color      mmr  \
# 2646    2010  Ford             Focus        SEDAN     red   5950.0
# 2648    2010  Ford             F-150  REGULAR CAB   white   4850.0
# 2649    2010  Ford  F-250 Super Duty     SUPERCAB   white   9525.0
# 2668    2010  Ford        Expedition          SUV   black  18550.0
# 2669    2010  Ford             Focus        SEDAN   white   5675.0
# ...      ...   ...               ...          ...     ...      ...
# 558059  2010  Ford             F-150     SUPERCAB  silver  14350.0
# 558342  2010  Ford             F-150    SUPERCREW   black  16600.0
# 558531  2010  Ford            Fusion        SEDAN  silver   7650.0
# 558587  2010  Ford             F-150     SUPERCAB  orange  34400.0
# 558588  2010  Ford           Mustang        COUPE    blue  17350.0
#
#         sellingprice                                 saledate
# 2646          6100.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)
# 2648          4100.0  Tue Dec 23 2014 13:00:00 GMT-0800 (PST)
# 2649          8750.0  Tue Dec 16 2014 12:00:00 GMT-0800 (PST)
# 2668         18600.0  Wed Dec 17 2014 12:15:00 GMT-0800 (PST)
# 2669          5400.0  Thu Dec 18 2014 12:00:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558059       16400.0  Fri Jun 19 2015 02:15:00 GMT-0700 (PDT)
# 558342       13700.0  Fri Jun 19 2015 02:15:00 GMT-0700 (PDT)
# 558531        7500.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)
# 558587       34250.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)
# 558588       16500.0  Fri Jun 19 2015 05:00:00 GMT-0700 (PDT)
#
# [3534 rows x 8 columns]

# %%
num_vendidos_ford = dict(carros_ford.value_counts("body").head(3))

# %%
num_vendidos_ford
# Out:
# {'SUPERCREW': 840, 'SUV': 793, 'SEDAN': 669}

# %%
sns.set()

f, ax = plt.subplots(figsize = (15, 5))

ax.bar_label(ax.bar(num_vendidos_ford .keys(), num_vendidos_ford .values()), padding = 0.3)
ax.bar(num_vendidos_ford .keys(), num_vendidos_ford .values(), color = sns.mpl_palette("Set2"))
#sns.barplot(data = num_vendidos, x = num_vendidos.keys(), y = num_vendidos.values, color = sns.mlp_palette("Set2" ))
ax.set_title("Top 5 Tipos de carros mais Vendidos da Ford ano 2010", size = "20")
ax.set_xlabel("Tipos de Carros", size = "16")
ax.set_ylabel("Vendas em números absolutos", size = "16")
ax.set_ylim((0, 1000))
# Out:
# (0.0, 1000.0)
